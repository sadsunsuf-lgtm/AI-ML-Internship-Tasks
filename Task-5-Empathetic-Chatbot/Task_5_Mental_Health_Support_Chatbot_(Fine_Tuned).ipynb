# %% [markdown]
# # Task 5: MindfulAI - Fine-Tuned Empathetic Chatbot
# This notebook contains the fine-tuning process for DistilGPT2 on the EmpatheticDialogues dataset.

# %%
# Your training and inference code goes here.
# (Paste your actual Python code from Colab into this cell if needed)
